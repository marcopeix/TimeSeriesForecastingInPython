# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## CNN

# %% [markdown]
# ### Single-step model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

conv_window = DataWindow(input_width=KERNEL_WIDTH, label_width=1, shift=1, label_columns=['traffic_volume'])
wide_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=1, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 15

mae_val = [0.083, 0.068, 0.033, 0.03]
mae_test = [0.081, 0.068, 0.029, 0.026]

# %%
cnn_model = Sequential([
    Conv1D(filters=32,
          kernel_size=(KERNEL_WIDTH,),
          activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(cnn_model, conv_window)

val_performance = {}
performance = {}

val_performance['CNN'] = cnn_model.evaluate(conv_window.val)
performance['CNN'] = cnn_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 2ms/step - loss: 0.0193 - mean_absolute_error: 0.0879 - val_loss: 0.0051 - val_mean_absolute_error: 0.0523
# Epoch 2/50
# 384/384 [==============================] - 0s 930us/step - loss: 0.0051 - mean_absolute_error: 0.0525 - val_loss: 0.0042 - val_mean_absolute_error: 0.0481
# Epoch 3/50
# 384/384 [==============================] - 0s 896us/step - loss: 0.0045 - mean_absolute_error: 0.0490 - val_loss: 0.0038 - val_mean_absolute_error: 0.0458
# Epoch 4/50
# 384/384 [==============================] - 0s 906us/step - loss: 0.0041 - mean_absolute_error: 0.0467 - val_loss: 0.0037 - val_mean_absolute_error: 0.0453
# Epoch 5/50
# 384/384 [==============================] - 0s 909us/step - loss: 0.0038 - mean_absolute_error: 0.0448 - val_loss: 0.0032 - val_mean_absolute_error: 0.0428
# Epoch 6/50
# 384/384 [==============================] - 0s 906us/step - loss: 0.0035 - mean_absolute_error: 0.0428 - val_loss: 0.0028 - val_mean_absolute_error: 0.0395
# Epoch 7/50
# 384/384 [==============================] - 0s 906us/step - loss: 0.0034 - mean_absolute_error: 0.0421 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 8/50
# 384/384 [==============================] - 0s 898us/step - loss: 0.0032 - mean_absolute_error: 0.0414 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 9/50
# 384/384 [==============================] - 0s 903us/step - loss: 0.0029 - mean_absolute_error: 0.0389 - val_loss: 0.0027 - val_mean_absolute_error: 0.0380
# Epoch 10/50
# 384/384 [==============================] - 0s 903us/step - loss: 0.0030 - mean_absolute_error: 0.0397 - val_loss: 0.0024 - val_mean_absolute_error: 0.0361
# Epoch 11/50
# 384/384 [==============================] - 0s 906us/step - loss: 0.0029 - mean_absolute_error: 0.0388 - val_loss: 0.0026 - val_mean_absolute_error: 0.0376
# Epoch 12/50
# 384/384 [==============================] - 0s 903us/step - loss: 0.0028 - mean_absolute_error: 0.0381 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 13/50
# 384/384 [==============================] - 0s 903us/step - loss: 0.0028 - mean_absolute_error: 0.0378 - val_loss: 0.0023 - val_mean_absolute_error: 0.0349
# Epoch 14/50
# 384/384 [==============================] - 0s 896us/step - loss: 0.0028 - mean_absolute_error: 0.0376 - val_loss: 0.0022 - val_mean_absolute_error: 0.0339
# Epoch 15/50
# 384/384 [==============================] - 0s 901us/step - loss: 0.0027 - mean_absolute_error: 0.0370 - val_loss: 0.0022 - val_mean_absolute_error: 0.0352
# Epoch 16/50
# 384/384 [==============================] - 0s 914us/step - loss: 0.0026 - mean_absolute_error: 0.0364 - val_loss: 0.0022 - val_mean_absolute_error: 0.0343
# Epoch 17/50
# 384/384 [==============================] - 0s 898us/step - loss: 0.0026 - mean_absolute_error: 0.0365 - val_loss: 0.0023 - val_mean_absolute_error: 0.0337
# 110/110 [==============================] - 0s 587us/step - loss: 0.0023 - mean_absolute_error: 0.0337

# %%
wide_conv_window.plot(cnn_model)

plt.savefig('figures/CH16_F05_peixeiro.png', dpi=300)

# %% [markdown]
# #### CNN + LSTM

# %%
cnn_lstm_model = Sequential([
    Conv1D(filters=32,
          kernel_size=(KERNEL_WIDTH,),
          activation='relu'),
    LSTM(32, return_sequences=True),
    LSTM(32, return_sequences=True),
    Dense(1)
])

history = compile_and_fit(cnn_lstm_model, conv_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 3ms/step - loss: 0.0295 - mean_absolute_error: 0.1117 - val_loss: 0.0069 - val_mean_absolute_error: 0.0611
# Epoch 2/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0572 - val_loss: 0.0049 - val_mean_absolute_error: 0.0510
# Epoch 3/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0498 - val_loss: 0.0039 - val_mean_absolute_error: 0.0460
# Epoch 4/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0448 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0414 - val_loss: 0.0028 - val_mean_absolute_error: 0.0385
# Epoch 6/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0397 - val_loss: 0.0026 - val_mean_absolute_error: 0.0391
# Epoch 7/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0395 - val_loss: 0.0024 - val_mean_absolute_error: 0.0354
# Epoch 8/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0382 - val_loss: 0.0025 - val_mean_absolute_error: 0.0384
# Epoch 9/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0377 - val_loss: 0.0023 - val_mean_absolute_error: 0.0354
# Epoch 10/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - val_loss: 0.0022 - val_mean_absolute_error: 0.0342
# Epoch 11/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0370 - val_loss: 0.0030 - val_mean_absolute_error: 0.0419
# Epoch 12/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0367 - val_loss: 0.0022 - val_mean_absolute_error: 0.0341
# Epoch 13/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0364 - val_loss: 0.0021 - val_mean_absolute_error: 0.0332
# Epoch 14/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0022 - val_mean_absolute_error: 0.0360
# Epoch 15/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0021 - val_mean_absolute_error: 0.0334
# Epoch 16/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0039 - val_mean_absolute_error: 0.0520
# Epoch 17/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0353 - val_loss: 0.0020 - val_mean_absolute_error: 0.0325
# Epoch 18/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0022 - val_mean_absolute_error: 0.0361
# Epoch 19/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0022 - val_mean_absolute_error: 0.0345
# Epoch 20/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0354 - val_loss: 0.0024 - val_mean_absolute_error: 0.0361
# 110/110 [==============================] - 0s 899us/step - loss: 0.0024 - mean_absolute_error: 0.0361

# %%
mae_val.extend([v[1] for v in val_performance.values()])
mae_test.extend([v[1] for v in performance.values()])

x = np.arange(6)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH16_F06_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-step model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=24, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 15

ms_mae_val = [0.352, 0.347, 0.088, 0.078, 0.070]
ms_mae_test = [0.347, 0.341, 0.076, 0.064, 0.058]

# %%
ms_cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_cnn_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['CNN'] = ms_cnn_model.evaluate(multi_window.val)
ms_performance['CNN'] = ms_cnn_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0345 - mean_absolute_error: 0.1229 - val_loss: 0.0163 - val_mean_absolute_error: 0.0857
# Epoch 2/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0141 - mean_absolute_error: 0.0791 - val_loss: 0.0157 - val_mean_absolute_error: 0.0828
# Epoch 3/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0137 - mean_absolute_error: 0.0778 - val_loss: 0.0157 - val_mean_absolute_error: 0.0869
# Epoch 4/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0134 - mean_absolute_error: 0.0772 - val_loss: 0.0149 - val_mean_absolute_error: 0.0802
# Epoch 5/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0133 - mean_absolute_error: 0.0767 - val_loss: 0.0148 - val_mean_absolute_error: 0.0820
# Epoch 6/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0131 - mean_absolute_error: 0.0760 - val_loss: 0.0145 - val_mean_absolute_error: 0.0802
# Epoch 7/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0755 - val_loss: 0.0149 - val_mean_absolute_error: 0.0781
# Epoch 8/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0752 - val_loss: 0.0149 - val_mean_absolute_error: 0.0791
# Epoch 9/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0127 - mean_absolute_error: 0.0746 - val_loss: 0.0143 - val_mean_absolute_error: 0.0783
# Epoch 10/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0127 - mean_absolute_error: 0.0746 - val_loss: 0.0147 - val_mean_absolute_error: 0.0825
# Epoch 11/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0126 - mean_absolute_error: 0.0741 - val_loss: 0.0147 - val_mean_absolute_error: 0.0768
# Epoch 12/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0125 - mean_absolute_error: 0.0737 - val_loss: 0.0143 - val_mean_absolute_error: 0.0780
# Epoch 13/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0124 - mean_absolute_error: 0.0733 - val_loss: 0.0144 - val_mean_absolute_error: 0.0764
# Epoch 14/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0124 - mean_absolute_error: 0.0733 - val_loss: 0.0141 - val_mean_absolute_error: 0.0771
# Epoch 15/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0730 - val_loss: 0.0143 - val_mean_absolute_error: 0.0753
# Epoch 16/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0725 - val_loss: 0.0143 - val_mean_absolute_error: 0.0802
# Epoch 17/50
# 383/383 [==============================] - 1s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0726 - val_loss: 0.0142 - val_mean_absolute_error: 0.0778
# 109/109 [==============================] - 0s 769us/step - loss: 0.0142 - mean_absolute_error: 0.0778

# %% [markdown]
# #### CNN + LSTM

# %%
ms_cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_cnn_lstm_model, multi_window)

ms_val_performance['CNN + LSTM'] = ms_cnn_lstm_model.evaluate(multi_window.val)
ms_performance['CNN + LSTM'] = ms_cnn_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 4s 6ms/step - loss: 0.0399 - mean_absolute_error: 0.1399 - val_loss: 0.0174 - val_mean_absolute_error: 0.0921
# Epoch 2/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0145 - mean_absolute_error: 0.0816 - val_loss: 0.0159 - val_mean_absolute_error: 0.0834
# Epoch 3/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0138 - mean_absolute_error: 0.0778 - val_loss: 0.0154 - val_mean_absolute_error: 0.0809
# Epoch 4/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0134 - mean_absolute_error: 0.0763 - val_loss: 0.0151 - val_mean_absolute_error: 0.0812
# Epoch 5/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0751 - val_loss: 0.0153 - val_mean_absolute_error: 0.0782absolute_error: 0
# Epoch 6/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0745 - val_loss: 0.0144 - val_mean_absolute_error: 0.0773
# Epoch 7/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0737 - val_loss: 0.0143 - val_mean_absolute_error: 0.0769
# Epoch 8/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0729 - val_loss: 0.0139 - val_mean_absolute_error: 0.0799
# Epoch 9/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0121 - mean_absolute_error: 0.0725 - val_loss: 0.0138 - val_mean_absolute_error: 0.0741
# Epoch 10/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0713 - val_loss: 0.0138 - val_mean_absolute_error: 0.0729
# Epoch 11/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0115 - mean_absolute_error: 0.0701 - val_loss: 0.0131 - val_mean_absolute_error: 0.0751
# Epoch 12/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0114 - mean_absolute_error: 0.0696 - val_loss: 0.0132 - val_mean_absolute_error: 0.0731
# Epoch 13/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0112 - mean_absolute_error: 0.0691 - val_loss: 0.0135 - val_mean_absolute_error: 0.0739
# Epoch 14/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0111 - mean_absolute_error: 0.0685 - val_loss: 0.0128 - val_mean_absolute_error: 0.0706
# Epoch 15/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0680 - val_loss: 0.0128 - val_mean_absolute_error: 0.0723
# Epoch 16/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0675 - val_loss: 0.0126 - val_mean_absolute_error: 0.0720
# Epoch 17/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0678 - val_loss: 0.0124 - val_mean_absolute_error: 0.0706
# Epoch 18/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0669 - val_loss: 0.0123 - val_mean_absolute_error: 0.0730
# Epoch 19/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0669 - val_loss: 0.0129 - val_mean_absolute_error: 0.0721
# Epoch 20/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0657 - val_loss: 0.0124 - val_mean_absolute_error: 0.0729
# Epoch 21/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0104 - mean_absolute_error: 0.0657 - val_loss: 0.0123 - val_mean_absolute_error: 0.0702
# Epoch 22/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0103 - mean_absolute_error: 0.0653 - val_loss: 0.0122 - val_mean_absolute_error: 0.0690
# Epoch 23/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0103 - mean_absolute_error: 0.0647 - val_loss: 0.0122 - val_mean_absolute_error: 0.07190103 - mean_absolute_error:
# Epoch 24/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0102 - mean_absolute_error: 0.0646 - val_loss: 0.0121 - val_mean_absolute_error: 0.0700
# Epoch 25/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0643 - val_loss: 0.0118 - val_mean_absolute_error: 0.0691
# Epoch 26/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0639 - val_loss: 0.0120 - val_mean_absolute_error: 0.0694
# Epoch 27/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0637 - val_loss: 0.0120 - val_mean_absolute_error: 0.0700
# Epoch 28/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0637 - val_loss: 0.0118 - val_mean_absolute_error: 0.0685
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0118 - mean_absolute_error: 0.0685A: 0s - loss: 0.0118 - mean_absolute_error: 0.068

# %%
ms_mae_val.extend([v[1] for v in ms_val_performance.values()])
ms_mae_test.extend([v[1] for v in ms_performance.values()])

x = np.arange(7)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH16_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-output model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

wide_mo_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=24, shift=1, label_columns=['temp', 'traffic_volume'])

# %%
# Values from chapter 15

mo_mae_val = [0.048, 0.039, 0.023, 0.020]
mo_mae_test = [0.047, 0.036, 0.020, 0.017]

# %%
mo_cnn_model = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_cnn_model, wide_mo_conv_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['CNN'] = mo_cnn_model.evaluate(wide_mo_conv_window.val)
mo_performance['CNN'] = mo_cnn_model.evaluate(wide_mo_conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0168 - mean_absolute_error: 0.0742 - val_loss: 0.0031 - val_mean_absolute_error: 0.0363
# Epoch 2/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0028 - mean_absolute_error: 0.0332 - val_loss: 0.0022 - val_mean_absolute_error: 0.0305
# Epoch 3/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0305 - val_loss: 0.0019 - val_mean_absolute_error: 0.0283
# Epoch 4/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0281 - val_loss: 0.0016 - val_mean_absolute_error: 0.0257
# Epoch 5/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0263 - val_loss: 0.0015 - val_mean_absolute_error: 0.0243
# Epoch 6/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0014 - val_mean_absolute_error: 0.0246
# Epoch 7/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0244 - val_loss: 0.0013 - val_mean_absolute_error: 0.0235
# Epoch 8/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0015 - mean_absolute_error: 0.0236 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 9/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0014 - mean_absolute_error: 0.0230 - val_loss: 0.0012 - val_mean_absolute_error: 0.0225
# Epoch 10/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0224 - val_loss: 0.0011 - val_mean_absolute_error: 0.0218
# Epoch 11/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0218 - val_loss: 0.0011 - val_mean_absolute_error: 0.0222
# Epoch 12/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0213
# Epoch 13/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0211 - val_loss: 9.8877e-04 - val_mean_absolute_error: 0.0202
# Epoch 14/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0207 - val_loss: 0.0010 - val_mean_absolute_error: 0.0201
# Epoch 15/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 9.7583e-04 - val_mean_absolute_error: 0.0201
# Epoch 16/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 9.5019e-04 - val_mean_absolute_error: 0.0193
# Epoch 17/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0201 - val_loss: 9.3074e-04 - val_mean_absolute_error: 0.0191
# Epoch 18/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 9.8691e-04 - val_mean_absolute_error: 0.0198
# Epoch 19/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0199 - val_loss: 9.0281e-04 - val_mean_absolute_error: 0.0187
# Epoch 20/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0196 - val_loss: 9.2462e-04 - val_mean_absolute_error: 0.0187
# Epoch 21/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0198 - val_loss: 9.0868e-04 - val_mean_absolute_error: 0.0190
# Epoch 22/50
# 384/384 [==============================] - 1s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0196 - val_loss: 9.0580e-04 - val_mean_absolute_error: 0.0187
# 109/109 [==============================] - 0s 787us/step - loss: 9.0580e-04 - mean_absolute_error: 0.0187

# %%
mo_cnn_lstm_model = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), activation='relu'),
    LSTM(32, return_sequences=True),
    Dense(units=2)
])

history = compile_and_fit(mo_cnn_lstm_model, wide_mo_conv_window)

mo_val_performance['CNN + LSTM'] = mo_cnn_model.evaluate(wide_mo_conv_window.val)
mo_performance['CNN + LSTM'] = mo_cnn_model.evaluate(wide_mo_conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 4s 7ms/step - loss: 0.0236 - mean_absolute_error: 0.0956 - val_loss: 0.0048 - val_mean_absolute_error: 0.0455
# Epoch 2/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0381 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 3/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0317 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 4/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0289 - val_loss: 0.0016 - val_mean_absolute_error: 0.0269
# Epoch 5/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0274 - val_loss: 0.0015 - val_mean_absolute_error: 0.0260
# Epoch 6/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0264 - val_loss: 0.0014 - val_mean_absolute_error: 0.0252
# Epoch 7/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0257 - val_loss: 0.0014 - val_mean_absolute_error: 0.0254
# Epoch 8/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0249 - val_loss: 0.0013 - val_mean_absolute_error: 0.0238
# Epoch 9/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0245 - val_loss: 0.0014 - val_mean_absolute_error: 0.0254
# Epoch 10/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0239 - val_loss: 0.0012 - val_mean_absolute_error: 0.0227
# Epoch 11/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0234 - val_loss: 0.0012 - val_mean_absolute_error: 0.0235
# Epoch 12/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0229 - val_loss: 0.0011 - val_mean_absolute_error: 0.0216
# Epoch 13/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0225 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 14/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0223 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 15/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0221 - val_loss: 0.0011 - val_mean_absolute_error: 0.0215
# Epoch 16/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0218 - val_loss: 0.0010 - val_mean_absolute_error: 0.0208
# Epoch 17/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0215 - val_loss: 0.0010 - val_mean_absolute_error: 0.0203
# Epoch 18/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 0.0010 - val_mean_absolute_error: 0.0205
# Epoch 19/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0209
# Epoch 20/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0211 - val_loss: 0.0010 - val_mean_absolute_error: 0.0206
# Epoch 21/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0209 - val_loss: 9.9385e-04 - val_mean_absolute_error: 0.0201
# Epoch 22/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0208 - val_loss: 9.7103e-04 - val_mean_absolute_error: 0.0201
# Epoch 23/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0207 - val_loss: 0.0011 - val_mean_absolute_error: 0.0221
# Epoch 24/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 25/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.5505e-04 - val_mean_absolute_error: 0.0198
# Epoch 26/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 9.5373e-04 - val_mean_absolute_error: 0.0197
# Epoch 27/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 0.0012 - val_mean_absolute_error: 0.0243
# Epoch 28/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 9.3097e-04 - val_mean_absolute_error: 0.0194
# Epoch 29/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0201 - val_loss: 8.8846e-04 - val_mean_absolute_error: 0.0189
# Epoch 30/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 9.5897e-04 - val_mean_absolute_error: 0.0202
# Epoch 31/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0198 - val_loss: 8.8002e-04 - val_mean_absolute_error: 0.0190
# Epoch 32/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0198 - val_loss: 8.8135e-04 - val_mean_absolute_error: 0.0191
# Epoch 33/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0197 - val_loss: 9.4276e-04 - val_mean_absolute_error: 0.0204
# Epoch 34/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0196 - val_loss: 8.6149e-04 - val_mean_absolute_error: 0.0186
# Epoch 35/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0195 - val_loss: 8.7378e-04 - val_mean_absolute_error: 0.0186
# Epoch 36/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0195 - val_loss: 8.6164e-04 - val_mean_absolute_error: 0.0185
# Epoch 37/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0193 - val_loss: 9.8339e-04 - val_mean_absolute_error: 0.0204
# 109/109 [==============================] - 0s 806us/step - loss: 9.0580e-04 - mean_absolute_error: 0.0187

# %%
wide_mo_conv_window.plot(mo_cnn_lstm_model)

# %%
mo_mae_val.extend([v[1] for v in mo_val_performance.values()])
mo_mae_test.extend([v[1] for v in mo_performance.values()])

x = np.arange(6)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.001, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.001, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH16_F08_peixeiro.png', dpi=300)
